# %% [markdown]
# # EHealth 705
#
# ## Python Tutorial: Getting Started with Python for Data Analysis
#
# ###  TA: Shirin Shahabinejad : [shahas8@mcmaster.ca](mailto:shahas8@mcmaster.ca)
#
# ## Table of Contents
# 1. [Introduction to Python](#Introduction-to-Python)
# 2. [Basic Python Commands](#Basic-Python-Commands)
# 3. [Introduction to Jupyter Notebooks](#Introduction-to-Jupyter-Notebooks)
# 4. [Running a Python Script in Jupyter](#Running-a-Python-Script-in-Jupyter)
# 5. [Q&A and Troubleshooting](#QA-and-Troubleshooting)
# 6. [Assignment](#Assignment)
#
#
#
# #### Date : Jan 17th, 2024

# %% [markdown]
# ## Introduction to Python <a id="Introduction-to-Python"></a>

# %% [markdown]
# ![image.png](attachment:image.png)
#
# #### What is Python?
#
# - **High-Level, Interpreted Language**: Known for readability and simplicity,  very beginner friendly programming language!
# - **cross platform**: we can build and run python applications on Windows, Mac, and Linux.
# - **Open-Source**: Free to use and distribute, even commercially.
# - **Career Growth**: Python skills are in high demand in many sectors, making them highly valuable for career advancement.
#
#
# #### Python in Data Analysis
#
# - **Versatility**: Ideal for various tasks, excels in data analysis.
# - **Powerful Libraries**: Pandas, NumPy, Matplotlib, Seaborn, Scikit-Learn.
# - **Ease of Learning**: Accessible to beginners in programming and data analysis.
# - **Large Community**: One of the largest programming communities worldwide.
# - **Continuous Development**: Always improving and expanding capabilities.
# - **Industry Standard**: Used by companies like Google, Facebook, Netflix.
# - **Research and Development**: Widely used in scientific research for data exploration.
# - **Wide Applicability**: Knowledge of Python opens doors to various roles in data science, machine learning, web development, and more.
#
#
#
# #### Conclusion
#
# - Python's simplicity, power, and community support make it a top choice for data analysis. Suitable for beginners and advanced users alike. It has large ecosystem of libraries, Frameworks and tools which means whatever you want to do, it is likely that someone else has done it before
#
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <a id="Basic-Python-Commands"></a>
# ## Basic Python Commands

# %% [markdown]
# ### Printing
#
# In Python, we ask a computer to print a message for us by writing `print()` and putting the message inside the parentheses and enclosed in quotation marks.  Below, we ask the computer to print the message `Hello, world!`.

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# ### Comments
#
# We use **comments** to annotate what code is doing.  They help other people to understand your code,To indicate to Python that a line is comment (and not Python code), you need to write a pound sign (`#`) as the very first character.

# %% [markdown]
# ### Arithmetic
#
# We can also print the value of some arithmetic operation (such as addition, subtraction, multiplication, or division).
#
# You can actually do a lot of calculations with python!  See the table below for some examples.
#
# <table style="width: 100%;">
# <tbody>
# <tr><th><b>Operation</b></th><th><b>Symbol</b></th><th><b>Example</b></th></tr>
# <tr>
# <td>Addition</td>
# <td>+</td>
# <td>1 + 2 = 3</td>
# </tr>
# <tr>
# <td>Subtraction</td>
# <td>-</td>
# <td>5 - 4 = 1</td>
# </tr>
# <tr>
# <td>Multiplication</td>
# <td>*</td>
# <td>2 * 4 = 8</td>
# </tr>
# <tr>
# <td>Division</td>
# <td>/</td>
# <td>6 / 3 = 2</td>
# </tr>
# <tr>
# <td>Exponent</td>
# <td>**</td>
# <td>3 ** 2 = 9</td>
# </tr>
# </tbody>
# </table>
#
#
#
#
# In general, Python follows the [PEMDAS rule](https://www.mathsisfun.com/operation-order-pemdas.html) when deciding the order of operations.

# %%
# Addition
sumation = 1 + 2
# Subtraction
difference = 5 - 4
# Multiplication
product = 2 * 4
# Division
Division = 8 // 3
#Exponent
Exponent = 3 **2

print(Division)

Remainder = 8 % 3
Remainder

# %% [markdown]
# ### Integers vs. Floats and Division in Python
#
# - **Integers**:
#   - Whole numbers without a decimal point.
#   - Used for numeric values without fractional components.
#   - Type: `int`.
#
# - **Floats**:
#   - Numbers with a decimal point.
#   - Used for representing real numbers and include fractional parts.
#   - Type: `float`.
#
# - **Division**:
#   - **True Division** (`/`): Dividing two integers results in a float.
#     - Example: `8 / 3` results in `2.666...`
#   - **Floor Division** (`//`): Divides and returns the integer part only.
#     - Example: `8 // 3` results in `2`.
#
# ### Various Types of Variables in Python
#
# | Data Type   | Description                                           | Example                       |
# |-------------|-------------------------------------------------------|-------------------------------|
# | Integer     | Whole numbers without a decimal point                 | `age = 30`                    |
# | Float       | Numbers with a decimal point                          | `temperature = 98.6`          |
# | String      | Sequence of characters, enclosed in quotes            | `greeting = "Hello"`          |
# | Boolean     | Represents two values: `True` or `False`              | `is_active = True`            |
# | List        | Ordered, mutable collection of items                  | `colors = ["red", "green", "blue"]` |
# | Tuple       | Ordered, immutable collection of items                | `dimensions = (800, 600)`     |
# | Set         | Unordered collection of unique items                  | `unique_numbers = {3, 1, 4, 2}` |
# | Dictionary  | Collection of key-value pairs                         | `student = {"name": "Alice", "age": 22}` |

# %%
# Integer Operations
a = 10
b = 5
sum = a + b  # Addition
print("Sum of integers:", sum)  # Expected Result: 15

# %%
# Float Operations
x = 2.5
y = 0.5
float_sum = x + y
print("Sum of floats:", float_sum)  # Expected Result: 3.0

# %%
# String Operations
first_name = "Shirin"
last_name = "Shahabi"
full_name = first_name + " " + last_name  # Concatenation
print("Full name:", full_name)

# %%
# Boolean Operations
flag1 = True
flag2 = False
boolean_and = flag1 and flag2  # Logical AND
print("Result of AND:", boolean_and)  # Expected Result: False

# %%
# List Operations
numbers = [1, 2, 3]
numbers.append(4)  # Adding an element
print("List after appending:", numbers)  # Expected Result: [1, 2, 3, 4]
numbers[-2]


numbers.append(4)  # Adding an element
print("List after appending:", numbers)  # Expected Result: [1, 2, 3, 4]

# %%
# Tuple Operations
coordinates = (10, 20)
x_coord = coordinates[0]  # Accessing an element
print("X coordinate:", x_coord)  # Expected Result: 10

# %%
# Set Operations
unique_numbers = {1, 2, 3}
unique_numbers.add(4)  # Adding an element
print("Set after adding:", unique_numbers)  # Expected Result: {1, 2, 3, 4}
unique_numbers.add(4)  # Adding an element
print("Set after adding:", unique_numbers)  # Expected Result: {1, 2, 3, 4}

# %%
# Dictionary Operations
student = {"name": "Alice", "age": 22}
student["age"] = 23  # Updating a value
print("Student age:", student["age"])  # Expected Result: 23

# %% [markdown]
# ### List Operations in Python
#
# Lists are versatile data structures for storing a collection of items. They are essential for data manipulation in Python.
#
# #### Basic Operations
#
# - **Adding Elements**: `append()`
#   - `numbers.append(4)` adds `4` to the end of `numbers`.
# - **Accessing Elements**: Using index
#   - `numbers[0]` accesses the first element.
# - **Removing Elements**: `remove()`
#   - `numbers.remove(2)` removes the first occurrence of `2`.
# - **Length of List**: `len()`
#   - `len(numbers)` returns the list's length.
# - **Slicing Lists**: `[start:end]`
#   - `numbers[0:2]` creates a sublist with the first two elements.
# - **Concatenating Lists**: Using `+`
#   - `numbers + [5, 6]` combines two lists.
# - **Iterating Through Lists**: `for` loop
#   - `for number in numbers: print(number)` iterates and prints each element.
#
# #### Practical Uses
#
# - **Data Collection and Analysis**: Ideal for gathering and organizing data.
# - **Iteration**: Useful in loops for repetitive tasks.
# - **Dynamic Storage**: Can grow or shrink as needed.
# - **Sorting and Filtering**: Supports data sorting and filtering methods.

# %%
# List Operations
numbers = [1, 2, 3]

# # Adding an Element
# numbers.append(4) 
# print("List after appending 4:", numbers)  # Expected Result: [1, 2, 3, 4]

# # Accessing Elements
# first_number = numbers[0]
# print("First number in the list:", first_number)  # Expected Result: 1

# # Removing an Element
# numbers.remove(2)
# print("List after removing 2:", numbers)  # Expected Result: [1, 3, 4]

# # Length of List
# length = len(numbers)
# print("Length of the list:", length)  # Expected Result: 3

# # Slicing a List
# sublist = numbers[0:2]
# print("Sublist (first two elements):", sublist)  # Expected Result: [1, 3]

# # Concatenating Lists
# additional_numbers = [5, 6]
# new_list = numbers + additional_numbers
# print("Concatenated list:", new_list)  # Expected Result: [1, 3, 4, 5, 6]

# # Iterating through a List
# print("Iterating through the list:")
# for number in numbers:
#     print(number)

# %%
will_not_work = "abc" + '3'
will_not_work

# %% [markdown]
# <a id="Introduction-to-Jupyter-Notebooks"></a>
# ## Introduction to Jupyter Notebooks

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Anaconda
#
# Anaconda is a free, open-source distribution for Python and R, used primarily for scientific computing, data science, and machine learning. It simplifies package management and deployment, and is widely used across different platforms.
#
# #### Advantages of Using Anaconda
#
# 1. **Pre-Installed Libraries**: Comes with most of the necessary Python libraries for data analysis, such as NumPy, Pandas, Matplotlib, Jupyter, and Scikit-learn.
#
# 2. **No Admin Privileges Required**: Can be installed easily on a work computer without needing administrative rights.
#
# 3. **Virtual Environment Management**: Provides a convenient tool for managing different virtual environments, allowing separate environments for different projects.
#
# 4. **Easy Installation**: Designed to be straightforward to install, reducing setup complexity.
#
# 5. **Beginner-Friendly**: The Anaconda Navigator offers a graphical user interface, making it accessible for beginners.
#
# 6. **Useful for All Experience Levels**: Equally beneficial for both beginners and experienced professionals in various stages of data analysis and scientific computing.
#
# Anaconda's comprehensive package management system and ease of use make it a preferred choice for many working in data science and related fields.

# %% [markdown]
# ### How to Install Anaconda
#
# Follow these steps to install Anaconda on your system. Anaconda is available for Windows, macOS, and Linux. The instructions below will guide you through the installation process.
#
# 1. **Download Anaconda**:
#    - Visit the [Anaconda Download Page](https://www.anaconda.com/products/distribution) and download the installer for your operating system.
#
# 2. **Installation Guide**:
#    - For macOS, follow the detailed instructions provided on the [Anaconda macOS Installation Guide](https://docs.anaconda.com/free/anaconda/install/mac-os/).
#    - For a visual and interactive guide, you can watch this [Installation Tutorial on YouTube](https://www.youtube.com/watch?v=WUeBzT43JyY).
#
# 3. **Run the Installer**:
#    - Execute the downloaded installer and follow the on-screen instructions.
#
# 4. **Verify Installation**:
#    - After installation, open Anaconda Navigator or use the command line to verify that Anaconda is installed correctly.
#
# 5. **Set Up Environments (Optional)**:
#    - Once installed, you can create separate environments for different projects using ***Anaconda Navigator*** or Conda commands in the terminal.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Brief Overview of Jupyter Notebook
#
# Jupyter is a Python environment that allows you to operate in a virtual “notebook” and is extremely useful in scientific computations. It gives you a way to combine code, images, plots, notes, etc. so you can essentially tell a story–how did I draw this conclusion from that data, and so on.
#
# During the majority of the stages of a data science project, it saves a major chunk of time!
#
#
# Jupyter Notebook is largely used for data analysis, data visualization, and further interactive, exploratory computing.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# <a id="Running-a-Python-Script-in-Jupyter"></a>
# ## Running a Python Script in Jupyter

# %% [markdown]
# ### Defining functions
#
# Built in functions are great, but we can only get so far with them before we need to start defining our own functions. Below is a simple example.
#
# The Following creates a function called `least_difference`, which takes three arguments, `a`, `b`, and `c`.
#
# Functions start with a header introduced by the `def` keyword. The indented block of code following the `:` is run when the function is called.
#
# `return` is another keyword uniquely associated with functions. When Python encounters a `return` statement, it exits the function immediately, and passes the value on the right hand side to the calling context.

# %%
will_work = "abc" + str(67.89)
will_work
# Out:
# 'abc67.89'

# %%
def least_difference(a, b, c):
    """Return the smallest difference between any two numbers
    among a, b and c.
    
    >>> least_difference(1, 5, -5)
    4
    """
    diff1 = abs(a - b)
    diff2 = abs(b - c)
    diff3 = abs(a - c)
    return min(diff1, diff2, diff3)

# %%
print(
    least_difference(1, 10, 100),
    least_difference(1, 10, 10),
    least_difference(5, 6, 7), # Python allows trailing commas in argument lists. How nice is that?
)
# Out:
# 9 0 1

# %%
def mod_5(x):
    """Return the remainder of x after dividing by 5"""
    return x % 5

print(
    'Which number is biggest?',
    max(100, 51, 14),
    'Which number is the biggest modulo 5?',
    max(100, 51, 14, key=mod_5),
    sep='\n',
)
# Out:
# Which number is biggest?
# 100
# Which number is the biggest modulo 5?
# 14

# %% [markdown]
# ## Conditions
# ​
# In programming, **conditions** are statements that are either `True` or `False`.  There are many different ways to write conditions in Python, but some of the most common ways of writing conditions just compare two different values.  For instance, you can check if 2 is greater than 3.

# %%
print(2 > 3)

# %%
2 == 3
# Out:
# False

# %% [markdown]
# For a list of common symbols you can use to construct conditions, check out the chart below.
#
# <table style="width: 100%;">
# <tbody>
# <tr><th><b>Symbol</b></th><th><b>Meaning</b></th></tr>
# <tr>
# <td>==</td>
# <td>equals</td>
# </tr>
# <tr>
# <td>!=</td>
# <td>does not equal</td>
# </tr>
# <tr>
# <td>&#60;</td>
# <td>less than</td>
# </tr>
# <tr>
# <td>&#60;=</td>
# <td>less than or equal to</td>
# </tr>
# <tr>
# <td>&#62;</td>
# <td>greater than</td>
# </tr>
# <tr>
# <td>&#62;=</td>
# <td>greater than or equal to</td>
# </tr>
# </tbody>
# </table>
#
#
# ### Conditional statements
#
# **Conditional statements** use conditions to modify how your function runs.  They check the value of a condition, and if the condition evaluates to `True`, then a certain block of code is executed.  (Otherwise, if the condition is `False`, then the code is not run.)
#
#
# ### "if" statements
#
# The simplest type of conditional statement is an "if" statement.  You can see an example of this in the `evaluate_temp()` function below.  The function accepts a body temperature (in Celcius) as input.
# - Initially, `message` is set to `"Normal temperature"`.
# - Then, if `temp > 38` is `True` (e.g., the body temperature is greater than 38°C), the message is updated to `"Fever!"`.  Otherwise, if `temp > 38` is False, then the message is not updated.
# - Finally, `message` is returned by the function.

# %%
def evaluate_temp(temp):
    # Set an initial message
    message = "Normal temperature."
    # Update value of message only if temperature greater than 38
    if temp > 38:
        message = "Fever!"
    return message

# %%
print(evaluate_temp(39))
# Out:
# Fever!

# %%
def evaluate_temp_with_else(temp):
    if temp > 38:
        message = "Fever!"
    else:
        message = "Normal temperature."
    return message

# %%
print(evaluate_temp_with_else(35))
# Out:
# Normal temperature.

# %%
def evaluate_temp_with_elif(temp):
    if temp > 38:
        message = "Fever!"
    elif temp > 35:
        message = "Normal temperature."
    else:
        message = "Low temperature."
    return message

# %%
evaluate_temp_with_elif(39)
# Out:
# 'Fever!'

# %% [markdown]
# ### While Loops
# - Used to execute a block of code repeatedly as long as a certain condition is true.
# - The condition is evaluated before each iteration, and if it's false, the loop is terminated.
# - Example usage includes iterating until a certain state is reached or a condition changes.

# %%
# While Loop Example
count = 0
while count < 5:
    print(count)
    count += 1

# %% [markdown]
# ### For Loops
# - Used to iterate over a sequence (like a list, tuple, or range).
# - Each iteration automatically takes the next item from the sequence and makes it available for use within the loop body.
# - Commonly used for iterating a fixed number of times, like traversing the elements in a collection.

# %%
# For Loop with List of Names
names = ["Alice", "Bob", "Charlie", "Diana"]
for name in names:
    print(name)
# Out:
# Alice
# Bob
# Charlie
# Diana

# %% [markdown]
# #### Differences
# - A `while` loop is generally used where the number of iterations is not known in advance.
# - A `for` loop is typically used where the number of iterations is known or determined by the sequence being iterated over.
# - `while` loops have a risk of becoming infinite if the condition never becomes false, while `for` loops will always terminate once the sequence is exhausted.

# %% [markdown]
# <a id="QA-and-Troubleshooting"></a>
# ## Q&A and Troubleshooting

# %% [markdown]
# If you encounter any trouble with installing Jupyter Notebook and Anaconda, please refer to the [Anaconda Website](https://www.anaconda.com/) for help and detailed instructions.
#
# For further assistance, feel free to contact the Teaching Assistant at [shahas8@mcmaster.ca](mailto:shahas8@mcmaster.ca).
#
# ### Alternative for Today's Session:
# If you're unable to install Jupyter Notebook and Anaconda today, you can use **Google Colab** as an alternative. Google Colab is a free, cloud-based service that supports Jupyter Notebooks. You can access it [here](https://colab.research.google.com/).

# %% [markdown]
# ### Additional Resources for Learning Jupyter Notebook
#
# For those looking to further expand their knowledge in Python, programming, and specifically in using Jupyter Notebook, consider exploring the following resources:
#
# 1. **Kaggle Courses**:
#    - [Python Course](https://www.kaggle.com/learn/python) on Kaggle: Comprehensive understanding of Python basics.
#    - [Intro to Programming Course](https://www.kaggle.com/learn/intro-to-programming) on Kaggle: Great for beginners in programming.
#
# 2. **Helpful Articles**:
#    - [Jupyter Notebook and Machine Learning](https://medium.com/@rramiz.rraza/jupyter-notebook-take-the-first-step-towards-machine-learning-and-data-analysis-9edef4b4b143): Insights on using Jupyter Notebook for machine learning and data analysis.
#    - [Beginner's Guide to Jupyter](https://medium.com/@DeOss/a-beginners-guide-to-start-working-with-jupyter-the-best-ide-for-data-analysis-in-python-b7530c3383c2): A comprehensive guide for beginners.
#    - [Setting Up a Virtual Environment in Python](https://medium.com/analytics-vidhya/how-to-set-a-virtual-environment-in-python-c2a9995d1843): A guide on how to create and manage Python virtual environments.
#
#
# 3. **Other Learning Resources**:
#    - [Jupyter Notebook Official Documentation](https://jupyter-notebook.readthedocs.io/en/stable/): Detailed guide and reference.
#    - [Jupyter Notebook Classic Installation Guide](https://docs.jupyter.org/en/latest/install/notebook-classic.html): Official guide on installing Jupyter Notebook Classic.
#    - [DataCamp's Jupyter Notebook Tutorial](https://www.datacamp.com/community/tutorials/tutorial-jupyter-notebook): A tutorial for beginners on DataCamp.
#    - [YouTube Tutorials](https://www.youtube.com/results?search_query=jupyter+notebook+tutorial): Various tutorials available for visual and interactive learning.
#
# These resources provide a broad range of learning materials for Python programming and Jupyter Notebook, suitable for both beginners and those looking to deepen their understanding.

# %% [markdown]
# ### Getting Help
#
# You saw the `abs` function in the previous tutorial, but what if you've forgotten what it does?
#
# The `help()` function is possibly the most important Python function you can learn. If you can remember how to use `help()`, you hold the key to understanding most other functions.
#
# Here is an example:

# %%
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.  Otherwise
#     the return value has the same type as the number.  ndigits may be negative.

# %%
help(least_difference)
# Out:
# Help on function least_difference in module __main__:
#
# least_difference(a, b, c)
#     Return the smallest difference between any two numbers
#     among a, b and c.
#
#     >>> least_difference(1, 5, -5)
#     4

# %% [markdown]
# <a id="Assignment"></a>
# ## Assignment

# %%
print("You've successfully run some Python code")
print("Congratulations!")

# %%
pi = 3.14159 # approximate
diameter = 3

# Create a variable called 'radius' equal to half the diameter
radius = diameter / 2
# Create a variable called 'area', using the formula for the area of a circle: pi times the radius squared
area = radius * radius * pi

# Check your answer to be 7.0685775
area

# %% [markdown]
# ### Exercise:
#
# You are helping a friend to calculate their weekly paycheck after taxes.
#
# They're in a 12% tax bracket (in other words, 12% of their salary is taken for taxes, and they only take home 88%),
#
#
# and They're paid hourly, at a rate of $15/hour.
#
# Write a function that calculates the paycheck based on the number of hours worked, test it with 40 hours, Answer = 528.0

# %% [markdown]
# ### Python Programming Exercise: Medication Dosage Calculation
#
# **Objective**: Write a Python function named `get_dose` that calculates the appropriate medication dosage based on the patient's weight.
#
# **Background**: Different weights require different medication dosages. Your task is to implement a function that uses the patient's weight to determine the correct dosage.
#
# **Function Specification**:
# - The function `get_dose` takes one parameter, `weight`, which is the weight of the patient in kilograms.
# - The dosage is determined as follows:
#   - 1.25 ml for anyone under 5.2 kg
#   - 2.5 ml for weights from 5.2 kg up to but not including 7.9 kg
#   - 3.75 ml for weights from 7.9 kg up to but not including 10.4 kg
#   - 5 ml for weights from 10.4 kg up to but not including 15.9 kg
#   - 7.5 ml for weights from 15.9 kg up to but not including 21.2 kg
#   - 10 ml for anyone 21.2 kg or over
# - The function should return the calculated dose in milliliters.
#
# **Task**:
# 1. Implement the `get_dose` function based on the above specifications.
# 2. Test your function with various weights to ensure it returns the correct dosage.
#
# **Example**:
# ```python
# print(get_dose(4))   # Should return 1.25
# print(get_dose(7))   # Should return 2.5
# print(get_dose(15))  # Should return 5
# print(get_dose(22))  # Should return 10

# %%
print(get_dose(4))   # Should return 1.25
